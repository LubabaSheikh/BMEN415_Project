# %%
# https://www.pluralsight.com/guides/deep-learning-model-perform-binary-classification

# Import Data
import pandas as pd
df = pd.read_csv('Group16_ClassificationData.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Splitting data set into train and test using Feature Matrix and Dependent Vector
properties = list(df.columns.values)
properties.remove('Outcome') # remove the outcome
print(properties)
X = df[properties]
y = df['Outcome'] # y vector is the Outcome
# Out:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

# %%
# Print X
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
# Print y
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
# The next step will be to divide the data into test and train sets. This is achieved using test_train_split function provided 
# in the model_selection class of sklearn module. 80% train, 20% test

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
# Model Creation
# The above code creates a Neural Network that has three layers. There are two layers of 16 nodes each and one output node. 
# The last node uses the sigmoid activation function. The other two layers use ReLU (Rectified Linear Units) as the activation function.
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(8,)), # needs to be 8 because of 8 features in data
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid),
])

# %%
# Model compilation
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=1)
test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/50
# 614/614 [==============================] - 3s 4ms/step - loss: 1.5801 - accuracy: 0.5407
# Epoch 2/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.8815 - accuracy: 0.5407
# Epoch 3/50
# 614/614 [==============================] - 3s 4ms/step - loss: 0.8016 - accuracy: 0.5814
# Epoch 4/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.7600 - accuracy: 0.6124
# Epoch 5/50
# 614/614 [==============================] - 3s 5ms/step - loss: 0.6944 - accuracy: 0.6010
# Epoch 6/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6634 - accuracy: 0.6596
# Epoch 7/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.7219 - accuracy: 0.6254
# Epoch 8/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6589 - accuracy: 0.6498
# Epoch 9/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6582 - accuracy: 0.6515
# Epoch 10/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6524 - accuracy: 0.6531
# Epoch 11/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6285 - accuracy: 0.6694
# Epoch 12/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6475 - accuracy: 0.6580
# Epoch 13/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6210 - accuracy: 0.6726
# Epoch 14/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6357 - accuracy: 0.6466
# Epoch 15/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6077 - accuracy: 0.6759
# Epoch 16/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6047 - accuracy: 0.6889
# Epoch 17/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5873 - accuracy: 0.7003
# Epoch 18/50
# 614/614 [==============================] - 3s 4ms/step - loss: 0.5784 - accuracy: 0.7052
# Epoch 19/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.5998 - accuracy: 0.6792
# Epoch 20/50
# 614/614 [==============================] - 3s 4ms/step - loss: 0.5844 - accuracy: 0.7036
# Epoch 21/50
# 614/614 [==============================] - 3s 4ms/step - loss: 0.5604 - accuracy: 0.7182
# Epoch 22/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.5781 - accuracy: 0.7150
# Epoch 23/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5665 - accuracy: 0.7052
# Epoch 24/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.5693 - accuracy: 0.7134
# Epoch 25/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.5559 - accuracy: 0.7248
# Epoch 26/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.5676 - accuracy: 0.7101
# Epoch 27/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5578 - accuracy: 0.7101
# Epoch 28/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.5478 - accuracy: 0.7345
# Epoch 29/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5614 - accuracy: 0.7117
# Epoch 30/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5382 - accuracy: 0.7231
# Epoch 31/50
# 614/614 [==============================] - 3s 5ms/step - loss: 0.5592 - accuracy: 0.7036
# Epoch 32/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.5303 - accuracy: 0.7280
# Epoch 33/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.5463 - accuracy: 0.7329
# Epoch 34/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.5359 - accuracy: 0.7313
# Epoch 35/50
# 614/614 [==============================] - 3s 5ms/step - loss: 0.5342 - accuracy: 0.7573
# Epoch 36/50
# 614/614 [==============================] - 3s 4ms/step - loss: 0.5442 - accuracy: 0.7248
# Epoch 37/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5153 - accuracy: 0.7410
# Epoch 38/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5333 - accuracy: 0.7345
# Epoch 39/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7296
# Epoch 40/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5248 - accuracy: 0.7557
# Epoch 41/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5367 - accuracy: 0.7378
# Epoch 42/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5287 - accuracy: 0.7476
# Epoch 43/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.5290 - accuracy: 0.7410
# Epoch 44/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.5249 - accuracy: 0.7362
# Epoch 45/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.5319 - accuracy: 0.7410
# Epoch 46/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5231 - accuracy: 0.7362
# Epoch 47/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5338 - accuracy: 0.7329
# Epoch 48/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.5266 - accuracy: 0.7410
# Epoch 49/50
# 614/614 [==============================] - 3s 5ms/step - loss: 0.5147 - accuracy: 0.7590
# Epoch 50/50
# 614/614 [==============================] - 3s 5ms/step - loss: 0.5096 - accuracy: 0.7508
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5275 - accuracy: 0.7532

# %%
# Use trained model to predict 
a= np.array([[4.02,70.86,62.05,7.0],[2.99,60.30,57.46,6.06]])
print(model.predict(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29804/3454212060.py in <module>
#       1 # Use trained model to predict
# ----> 2 a= np.array([[4.02,70.86,62.05,7.0],[2.99,60.30,57.46,6.06]])
#       3 print(model.predict(a))
#
# NameError: name 'np' is not defined
